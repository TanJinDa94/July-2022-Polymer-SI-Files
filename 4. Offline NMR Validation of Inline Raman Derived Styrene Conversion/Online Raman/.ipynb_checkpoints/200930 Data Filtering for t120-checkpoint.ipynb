# %% [markdown]
# # Import Relevant Packages

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Import Raw Data and Find Vinyl Peak

# %%
# Import t0 raw data
df = pd.read_csv('t120_1.txt', delimiter = '\t') # Tab delimited.
df = df.drop(df.columns[0:3], axis=1) # Drop 1st 3 columns.
df
# Out:
#      99.246077  103.757292  108.266327  112.771060  117.273618  121.774004  \
# 0       1183.0      1450.0      1682.0      2021.0      2060.0      2331.0
# 1       1200.0      1530.0      1772.0      2112.0      2178.0      2359.0
# 2       1196.0      1551.0      1706.0      1992.0      2301.0      2351.0
# 3       1245.0      1557.0      1753.0      2036.0      2157.0      2453.0
# 4       1292.0      1525.0      1833.0      2037.0      2248.0      2554.0
# ..         ...         ...         ...         ...         ...         ...
# 297     2375.0      2901.0      3368.0      3745.0      4290.0      4592.0
# 298     2317.0      2802.0      3486.0      3821.0      4290.0      4514.0
# 299     2291.0      2781.0      3397.0      3994.0      4269.0      4561.0
# 300     2233.0      2898.0      3500.0      3976.0      4076.0      4622.0
# 301     2302.0      2900.0      3524.0      4012.0      4239.0      4684.0
#
#      126.270097  130.761902  135.255782  139.743259  ...  2473.071609  \
# 0        2484.0      2717.0      2847.0      2889.0  ...       5614.0
# 1        2522.0      2686.0      2912.0      2862.0  ...       5838.0
# 2        2476.0      2628.0      2896.0      2957.0  ...       5846.0
# 3        2585.0      2802.0      2950.0      3039.0  ...       5870.0
# 4        2564.0      2717.0      2913.0      3102.0  ...       5881.0
# ..          ...         ...         ...         ...  ...          ...
# 297      4938.0      5321.0      5619.0      5940.0  ...      13814.0
# 298      5097.0      5375.0      5786.0      6203.0  ...      14034.0
# 299      4951.0      5270.0      5643.0      6164.0  ...      13776.0
# 300      5100.0      5438.0      5840.0      6065.0  ...      14140.0
# 301      4977.0      5405.0      5710.0      6156.0  ...      13926.0
#
#      2476.234866  2479.395275  2482.556077  2485.715652  2488.872385  \
# 0         5694.0       5632.0       5621.0       5673.0       5622.0
# 1         5687.0       5724.0       5717.0       5770.0       5768.0
# 2         5926.0       5908.0       5870.0       5824.0       6030.0
# 3         5783.0       6098.0       5971.0       6024.0       5954.0
# 4         6061.0       6128.0       6021.0       6001.0       5858.0
# ..           ...          ...          ...          ...          ...
# 297      13844.0      13463.0      13780.0      13358.0      13504.0
# 298      13767.0      13642.0      13403.0      13473.0      13543.0
# 299      13860.0      13848.0      13715.0      13545.0      13892.0
# 300      14002.0      13863.0      13701.0      13697.0      13415.0
# 301      14128.0      14061.0      14013.0      13732.0      13572.0
#
#      2492.029510  2495.183795  2498.333627  2501.485469
# 0         5718.0       5625.0       5770.0       5565.0
# 1         5745.0       5629.0       5674.0       5850.0
# 2         6004.0       5841.0       5864.0       5897.0
# 3         6040.0       5874.0       5923.0       5731.0
# 4         5926.0       6001.0       6021.0       6084.0
# ..           ...          ...          ...          ...
# 297      13743.0      13341.0      13249.0      13318.0
# 298      13405.0      13387.0      13432.0      13323.0
# 299      13593.0      13706.0      13417.0      13367.0
# 300      13582.0      13352.0      13426.0      13455.0
# 301      13727.0      13713.0      13452.0      13495.0
#
# [302 rows x 637 columns]

# %%
# Find out Vinyl Peak Wavenumber = ~1630 cm-1 Region

df.iloc[:, 375:385].plot()
plt.show() 
# Plot all columns in the region to see which intensity is the highest. Pick that index location.
# Wavenumber at 1628.104424 cm-1 is the vinyl peak with the highest intensity.

# %%
# df.loc[:,'1629.209334'] --> When using loc.
df.columns.get_loc('1629.245625') #--> Use the get_loc command on the column index to find the index location. 
# df.iloc[:,378] --> When using iloc

# Column index 378 is equivalent to column label 1628.659771. Use relevant parameter for iloc and loc respectively.
# Out:
# 378

# %% [markdown]
# # Filter Relevant Spectra

# %%
# Zoom into Relevant Region
df.loc[60:250,'1629.245625'].plot()
plt.xlabel('Spectral Index')
plt.ylabel('Intensity')
plt.title('0 Hours')
plt.show()

# %%
# Extract Data From Steady State Region
# Zoom into Relevant Region
df.loc[200:210,'1629.245625'].plot()
plt.xlabel('Spectral Index')
plt.ylabel('Intensity')
plt.title('0 Hours')
plt.show()

# %% [markdown]
# # Present Summary Statistics of Extracted Data

# %%
# Present summary statistics steady state.
df.loc[200:210,'1629.245625'].describe()
# Out:
# count      11.000000
# mean     6608.818182
# std        84.870275
# min      6402.000000
# 25%      6606.000000
# 50%      6640.000000
# 75%      6653.500000
# max      6695.000000
# Name: 1629.245625, dtype: float64

# %%
df_ss = df.iloc[200:210]

# %%
# Inspect df_ss.
df_ss
# Out:
#      99.246077  103.757292  108.266327  112.771060  117.273618  121.774004  \
# 200     6104.0      6815.0      6920.0      6713.0      6250.0      5632.0
# 201     6344.0      6782.0      7128.0      6779.0      6330.0      5676.0
# 202     6441.0      7005.0      7090.0      6856.0      6306.0      5796.0
# 203     6286.0      7051.0      6946.0      6909.0      6234.0      5791.0
# 204     6317.0      6989.0      7266.0      6803.0      6135.0      5655.0
# 205     6334.0      7031.0      7154.0      6880.0      6260.0      5736.0
# 206     6261.0      7102.0      7400.0      6838.0      6327.0      5922.0
# 207     6415.0      7030.0      7222.0      6899.0      6229.0      5782.0
# 208     6368.0      7175.0      7275.0      6943.0      6274.0      5843.0
# 209     6400.0      7135.0      7221.0      7123.0      6410.0      5906.0
#
#      126.270097  130.761902  135.255782  139.743259  ...  2473.071609  \
# 200      5099.0      4675.0      4303.0      4047.0  ...        310.0
# 201      5282.0      4694.0      4446.0      3997.0  ...        259.0
# 202      5278.0      4743.0      4463.0      4246.0  ...        278.0
# 203      5165.0      4798.0      4395.0      3971.0  ...        277.0
# 204      5106.0      4858.0      4593.0      4204.0  ...        304.0
# 205      5403.0      4732.0      4467.0      4081.0  ...        266.0
# 206      5265.0      4696.0      4604.0      4109.0  ...        263.0
# 207      5350.0      4882.0      4548.0      4159.0  ...        241.0
# 208      5313.0      4805.0      4581.0      4260.0  ...        264.0
# 209      5293.0      4935.0      4477.0      4229.0  ...        284.0
#
#      2476.234866  2479.395275  2482.556077  2485.715652  2488.872385  \
# 200        291.0        334.0        340.0        290.0        322.0
# 201        292.0        342.0        358.0        296.0        265.0
# 202        280.0        323.0        375.0        230.0        321.0
# 203        317.0        335.0        328.0        316.0        276.0
# 204        268.0        301.0        366.0        360.0        288.0
# 205        317.0        304.0        374.0        280.0        252.0
# 206        289.0        295.0        311.0        317.0        267.0
# 207        327.0        332.0        367.0        290.0        358.0
# 208        278.0        273.0        328.0        221.0        272.0
# 209        283.0        305.0        344.0        333.0        326.0
#
#      2492.029510  2495.183795  2498.333627  2501.485469
# 200        288.0        286.0        257.0        206.0
# 201        378.0        268.0        261.0        239.0
# 202        353.0        349.0        305.0        241.0
# 203        347.0        247.0        279.0        257.0
# 204        341.0        342.0        266.0        238.0
# 205        377.0        265.0        244.0        261.0
# 206        372.0        261.0        255.0        222.0
# 207        360.0        327.0        306.0        270.0
# 208        374.0        290.0        212.0        242.0
# 209        403.0        288.0        238.0        244.0
#
# [10 rows x 637 columns]

# %%
# Write extracted dataframe to csv file.
df_ss.to_csv(r'C:\Users\Tan Jin Da\Desktop\A STAR\Controlled Polymerization Experiments\200930 Continuous Flow for NMR and Raman Triplicate Experiment 6 (1 mol% AIBN, 85 deg)\Online Raman\df_ss_t120.csv')
