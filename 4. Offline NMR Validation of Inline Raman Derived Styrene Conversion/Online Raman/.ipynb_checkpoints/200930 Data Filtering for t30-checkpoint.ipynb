# %% [markdown]
# # Import Relevant Packages

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Import Raw Data and Find Vinyl Peak

# %%
# Import t0 raw data
df = pd.read_csv('t30_1.txt', delimiter = '\t') # Tab delimited.
df = df.drop(df.columns[0:3], axis=1) # Drop 1st 3 columns.
df
# Out:
#     99.246077  103.757292  108.266327  112.771060  117.273618  121.774004  \
# 0       536.0       697.0       816.0       922.0       896.0      1078.0
# 1       578.0       643.0       835.0       960.0      1049.0      1130.0
# 2       603.0       684.0       778.0       977.0      1059.0      1112.0
# 3       593.0       757.0       944.0      1005.0      1064.0      1168.0
# 4       605.0       738.0       920.0       955.0      1072.0      1047.0
# ..        ...         ...         ...         ...         ...         ...
# 92     1736.0      2172.0      2723.0      3031.0      3344.0      3621.0
# 93     1739.0      2171.0      2683.0      3128.0      3325.0      3672.0
# 94     1764.0      2274.0      2779.0      3087.0      3433.0      3710.0
# 95     1707.0      2137.0      2615.0      3105.0      3282.0      3589.0
# 96     1661.0      2334.0      2788.0      3086.0      3370.0      3764.0
#
#     126.270097  130.761902  135.255782  139.743259  ...  2473.071609  \
# 0       1112.0      1189.0      1204.0      1310.0  ...       3390.0
# 1       1160.0      1245.0      1264.0      1328.0  ...       3438.0
# 2       1251.0      1234.0      1261.0      1314.0  ...       3449.0
# 3       1187.0      1242.0      1298.0      1359.0  ...       3621.0
# 4       1203.0      1139.0      1325.0      1338.0  ...       3664.0
# ..         ...         ...         ...         ...  ...          ...
# 92      3819.0      4021.0      4450.0      4677.0  ...       7895.0
# 93      3925.0      4187.0      4559.0      4659.0  ...       7923.0
# 94      3989.0      4158.0      4501.0      4729.0  ...       7853.0
# 95      4002.0      4045.0      4666.0      4702.0  ...       7855.0
# 96      3976.0      4190.0      4485.0      4718.0  ...       7795.0
#
#     2476.234866  2479.395275  2482.556077  2485.715652  2488.872385  \
# 0        3418.0       3484.0       3622.0       3395.0       3595.0
# 1        3444.0       3562.0       3740.0       3409.0       3528.0
# 2        3559.0       3609.0       3779.0       3664.0       3781.0
# 3        3681.0       3672.0       3643.0       3520.0       3603.0
# 4        3556.0       3638.0       3673.0       3656.0       3684.0
# ..          ...          ...          ...          ...          ...
# 92       7900.0       7915.0       7802.0       7861.0       7709.0
# 93       7785.0       7648.0       7771.0       7794.0       7945.0
# 94       7772.0       7830.0       7905.0       7817.0       7762.0
# 95       7740.0       7871.0       7882.0       7700.0       7843.0
# 96       7996.0       7909.0       7976.0       7871.0       7920.0
#
#     2492.029510  2495.183795  2498.333627  2501.485469
# 0        3465.0       3506.0       3474.0       3559.0
# 1        3731.0       3628.0       3572.0       3531.0
# 2        3620.0       3755.0       3704.0       3611.0
# 3        3862.0       3722.0       3747.0       3630.0
# 4        3758.0       3767.0       3751.0       3840.0
# ..          ...          ...          ...          ...
# 92       7929.0       7725.0       7688.0       7554.0
# 93       7767.0       7727.0       7719.0       7480.0
# 94       7914.0       7727.0       7623.0       7792.0
# 95       7887.0       7745.0       7859.0       7834.0
# 96       7767.0       7833.0       7758.0       7724.0
#
# [97 rows x 637 columns]

# %%
# Find out Vinyl Peak Wavenumber = ~1630 cm-1 Region

df.iloc[:, 375:385].plot()
plt.show() 
# Plot all columns in the region to see which intensity is the highest. Pick that index location.
# Wavenumber at 1628.104424 cm-1 is the vinyl peak with the highest intensity.

# %%
# df.loc[:,'1629.209334'] --> When using loc.
df.columns.get_loc('1629.245625') #--> Use the get_loc command on the column index to find the index location. 
# df.iloc[:,378] --> When using iloc

# Column index 378 is equivalent to column label 1628.659771. Use relevant parameter for iloc and loc respectively.
# Out:
# 378

# %% [markdown]
# # Filter Relevant Spectra

# %%
# Zoom into Relevant Region
df.loc[:70,'1629.245625'].plot()
plt.xlabel('Spectral Index')
plt.ylabel('Intensity')
plt.title('0 Hours')
plt.show()

# %%
# Extract Data From Steady State Region
# Zoom into Relevant Region
df.loc[30:40,'1629.245625'].plot()
plt.xlabel('Spectral Index')
plt.ylabel('Intensity')
plt.title('0 Hours')
plt.show()

# %% [markdown]
# # Present Summary Statistics of Extracted Data

# %%
# Present summary statistics steady state.
df.loc[30:40,'1629.245625'].describe()
# Out:
# count       11.000000
# mean     12360.818182
# std        167.557046
# min      11999.000000
# 25%      12270.500000
# 50%      12365.000000
# 75%      12491.500000
# max      12591.000000
# Name: 1629.245625, dtype: float64

# %%
df_ss = df.iloc[30:40]

# %%
# Inspect df_ss.
df_ss
# Out:
#     99.246077  103.757292  108.266327  112.771060  117.273618  121.774004  \
# 30     8383.0      9571.0      9602.0      8984.0      8528.0      7701.0
# 31     8382.0      9326.0      9555.0      9192.0      8613.0      7881.0
# 32     8271.0      9474.0      9891.0      9214.0      8752.0      7845.0
# 33     8227.0      9638.0      9487.0      9194.0      8625.0      7973.0
# 34     8389.0      9518.0      9641.0      9479.0      8395.0      7911.0
# 35     8466.0      9556.0      9912.0      9550.0      8673.0      8083.0
# 36     8557.0      9554.0      9895.0      9492.0      8735.0      7969.0
# 37     8341.0      9494.0      9684.0      9305.0      8791.0      7800.0
# 38     8452.0      9809.0      9867.0      9490.0      8536.0      7993.0
# 39     8670.0      9675.0     10143.0      9586.0      8775.0      7931.0
#
#     126.270097  130.761902  135.255782  139.743259  ...  2473.071609  \
# 30      7085.0      6607.0      6299.0      5629.0  ...        253.0
# 31      7302.0      6622.0      6133.0      5629.0  ...        237.0
# 32      7177.0      6552.0      6229.0      5796.0  ...        170.0
# 33      7168.0      6632.0      6322.0      5698.0  ...        177.0
# 34      7044.0      6699.0      6326.0      5740.0  ...        181.0
# 35      7338.0      6683.0      6244.0      5863.0  ...        210.0
# 36      7186.0      6535.0      6041.0      5652.0  ...        177.0
# 37      7411.0      6544.0      6240.0      5611.0  ...        182.0
# 38      7344.0      6703.0      6102.0      5871.0  ...        154.0
# 39      7370.0      6782.0      6279.0      5728.0  ...        157.0
#
#     2476.234866  2479.395275  2482.556077  2485.715652  2488.872385  \
# 30        192.0        273.0        272.0        189.0        220.0
# 31        183.0        276.0        290.0        256.0        220.0
# 32        203.0        256.0        309.0        206.0        225.0
# 33        192.0        256.0        284.0        220.0        204.0
# 34        247.0        198.0        249.0        226.0        240.0
# 35        239.0        241.0        279.0        222.0        187.0
# 36        208.0        219.0        292.0        208.0        176.0
# 37        190.0        207.0        255.0        218.0        203.0
# 38        209.0        180.0        310.0        215.0        223.0
# 39        165.0        215.0        259.0        258.0        173.0
#
#     2492.029510  2495.183795  2498.333627  2501.485469
# 30        257.0        180.0        234.0        190.0
# 31        276.0        239.0        240.0        193.0
# 32        313.0        196.0        197.0        187.0
# 33        336.0        183.0        252.0        115.0
# 34        310.0        194.0        201.0        214.0
# 35        314.0        236.0        188.0        155.0
# 36        251.0        147.0        243.0        203.0
# 37        298.0        232.0        157.0        151.0
# 38        292.0        216.0        191.0        167.0
# 39        277.0        168.0        220.0        185.0
#
# [10 rows x 637 columns]

# %%
# Write extracted dataframe to csv file.
df_ss.to_csv(r'C:\Users\Tan Jin Da\Desktop\A STAR\Controlled Polymerization Experiments\200930 Continuous Flow for NMR and Raman Triplicate Experiment 6 (1 mol% AIBN, 85 deg)\Online Raman\df_ss_t30.csv')
