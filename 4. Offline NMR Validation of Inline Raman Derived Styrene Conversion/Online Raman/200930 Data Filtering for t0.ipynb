# %% [markdown]
# # Import Relevant Packages

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Import Raw Data and Find Vinyl Peak

# %%
# Import t0 raw data
df = pd.read_csv('t0_1.txt', delimiter = '\t') # Tab delimited.
df = df.drop(df.columns[0:3], axis=1) # Drop 1st 3 columns.
df
# Out:
#     99.246077  103.757292  108.266327  112.771060  117.273618  121.774004  \
# 0       704.0       865.0      1008.0      1142.0      1258.0      1354.0
# 1       622.0       746.0       925.0      1132.0      1180.0      1188.0
# 2       659.0       820.0       974.0      1094.0      1174.0      1258.0
# 3       659.0       814.0       954.0      1052.0      1187.0      1301.0
# 4       669.0       818.0       993.0      1159.0      1203.0      1267.0
# ..        ...         ...         ...         ...         ...         ...
# 67      462.0       498.0       582.0       767.0       811.0       881.0
# 68      422.0       634.0       724.0       802.0       802.0       931.0
# 69      484.0       485.0       629.0       677.0       856.0       890.0
# 70      573.0       567.0       686.0       875.0       811.0       856.0
# 71      503.0       582.0       643.0       818.0       802.0       905.0
#
#     126.270097  130.761902  135.255782  139.743259  ...  2473.071609  \
# 0       1410.0      1358.0      1502.0      1689.0  ...       4248.0
# 1       1291.0      1364.0      1510.0      1433.0  ...       4052.0
# 2       1243.0      1410.0      1435.0      1520.0  ...       4026.0
# 3       1330.0      1405.0      1425.0      1471.0  ...       4054.0
# 4       1337.0      1425.0      1447.0      1418.0  ...       4101.0
# ..         ...         ...         ...         ...  ...          ...
# 67       944.0       951.0      1026.0      1041.0  ...       1884.0
# 68       990.0      1042.0      1052.0      1025.0  ...       1950.0
# 69       975.0       907.0      1037.0      1022.0  ...       1874.0
# 70      1038.0       945.0      1113.0      1101.0  ...       2001.0
# 71       939.0       870.0      1050.0      1031.0  ...       1950.0
#
#     2476.234866  2479.395275  2482.556077  2485.715652  2488.872385  \
# 0        4082.0       4134.0       4140.0       4111.0       4206.0
# 1        4128.0       4195.0       4247.0       4096.0       4096.0
# 2        4034.0       4042.0       4159.0       4145.0       4142.0
# 3        4102.0       4204.0       4078.0       4168.0       4218.0
# 4        4128.0       4086.0       4260.0       4283.0       4083.0
# ..          ...          ...          ...          ...          ...
# 67       1892.0       1970.0       2060.0       1834.0       1973.0
# 68       1941.0       2019.0       1994.0       2035.0       1976.0
# 69       2025.0       1945.0       2080.0       1954.0       2032.0
# 70       1997.0       2058.0       2129.0       2066.0       2075.0
# 71       1945.0       2075.0       2159.0       1966.0       1959.0
#
#     2492.029510  2495.183795  2498.333627  2501.485469
# 0        4381.0       4285.0       4280.0       4129.0
# 1        4135.0       4120.0       4099.0       4192.0
# 2        4298.0       4156.0       4199.0       4281.0
# 3        4272.0       4189.0       4191.0       4149.0
# 4        4406.0       4369.0       4339.0       4190.0
# ..          ...          ...          ...          ...
# 67       2098.0       1946.0       1978.0       2004.0
# 68       2078.0       2105.0       2001.0       2025.0
# 69       2031.0       2069.0       1947.0       1984.0
# 70       2094.0       2133.0       2045.0       2013.0
# 71       2180.0       2043.0       1990.0       2025.0
#
# [72 rows x 637 columns]

# %%
# Find out Vinyl Peak Wavenumber = ~1630 cm-1 Region

df.iloc[:, 375:385].plot()
plt.show() 
# Plot all columns in the region to see which intensity is the highest. Pick that index location.
# Wavenumber at 1628.104424 cm-1 is the vinyl peak with the highest intensity.

# %%
# df.loc[:,'1629.209334'] --> When using loc.
df.columns.get_loc('1629.245625') #--> Use the get_loc command on the column index to find the index location. 
# df.iloc[:,378] --> When using iloc

# Column index 378 is equivalent to column label 1628.659771. Use relevant parameter for iloc and loc respectively.
# Out:
# 378

# %% [markdown]
# # Filter Relevant Spectra

# %%
# Zoom into Relevant Region
df.loc[:70,'1629.245625'].plot()
plt.xlabel('Spectral Index')
plt.ylabel('Intensity')
plt.title('0 Hours')
plt.show()

# %%
# Extract Data From Steady State Region
# Zoom into Relevant Region
df.loc[30:40,'1629.245625'].plot()
plt.xlabel('Spectral Index')
plt.ylabel('Intensity')
plt.title('0 Hours')
plt.show()

# %% [markdown]
# # Present Summary Statistics of Extracted Data

# %%
# Present summary statistics steady state.
df.loc[30:40,'1629.245625'].describe()
# Out:
# count       11.000000
# mean     15405.363636
# std        152.493457
# min      15221.000000
# 25%      15315.500000
# 50%      15403.000000
# 75%      15440.000000
# max      15751.000000
# Name: 1629.245625, dtype: float64

# %%
df_ss = df.iloc[30:40]

# %%
# Inspect df_ss.
df_ss
# Out:
#     99.246077  103.757292  108.266327  112.771060  117.273618  121.774004  \
# 30     8698.0      9983.0     10426.0     10205.0      9555.0      8727.0
# 31     8870.0      9994.0     10357.0     10150.0      9462.0      8573.0
# 32     8662.0     10050.0     10424.0     10245.0      9349.0      8606.0
# 33     8847.0     10102.0     10386.0     10168.0      9287.0      8512.0
# 34     8642.0      9892.0     10382.0      9911.0      9451.0      8674.0
# 35     8773.0      9884.0     10235.0      9958.0      9345.0      8605.0
# 36     8804.0     10112.0     10199.0     10225.0      9128.0      8505.0
# 37     8725.0      9912.0     10207.0     10009.0      9230.0      8452.0
# 38     8555.0      9887.0     10293.0     10139.0      9424.0      8528.0
# 39     8766.0      9997.0     10308.0     10163.0      9345.0      8502.0
#
#     126.270097  130.761902  135.255782  139.743259  ...  2473.071609  \
# 30      7914.0      7108.0      6612.0      6212.0  ...        266.0
# 31      7923.0      7159.0      6570.0      6163.0  ...        272.0
# 32      7858.0      7169.0      6499.0      6339.0  ...        347.0
# 33      7943.0      7256.0      6733.0      6222.0  ...        264.0
# 34      7825.0      7151.0      6780.0      6131.0  ...        270.0
# 35      7847.0      7124.0      6782.0      6269.0  ...        285.0
# 36      7837.0      7167.0      6643.0      6067.0  ...        227.0
# 37      7936.0      6983.0      6598.0      6138.0  ...        307.0
# 38      7803.0      7022.0      6471.0      6005.0  ...        286.0
# 39      7682.0      7011.0      6628.0      6157.0  ...        290.0
#
#     2476.234866  2479.395275  2482.556077  2485.715652  2488.872385  \
# 30        319.0        313.0        355.0        323.0        313.0
# 31        253.0        335.0        351.0        276.0        302.0
# 32        242.0        372.0        362.0        278.0        292.0
# 33        289.0        348.0        366.0        348.0        308.0
# 34        249.0        347.0        379.0        306.0        310.0
# 35        285.0        313.0        427.0        306.0        288.0
# 36        240.0        336.0        349.0        253.0        293.0
# 37        276.0        296.0        383.0        311.0        338.0
# 38        334.0        318.0        351.0        303.0        309.0
# 39        297.0        318.0        335.0        280.0        334.0
#
#     2492.029510  2495.183795  2498.333627  2501.485469
# 30        392.0        323.0        306.0        232.0
# 31        389.0        307.0        248.0        276.0
# 32        364.0        249.0        318.0        278.0
# 33        383.0        346.0        334.0        240.0
# 34        438.0        290.0        363.0        292.0
# 35        353.0        272.0        284.0        260.0
# 36        357.0        259.0        306.0        182.0
# 37        383.0        330.0        297.0        244.0
# 38        376.0        277.0        281.0        241.0
# 39        359.0        294.0        293.0        251.0
#
# [10 rows x 637 columns]

# %%
# Write extracted dataframe to csv file.
df_ss.to_csv(r'C:\Users\Tan Jin Da\Desktop\A STAR\Controlled Polymerization Experiments\200930 Continuous Flow for NMR and Raman Triplicate Experiment 6 (1 mol% AIBN, 85 deg)\Online Raman\df_ss_t0.csv')
